# %%
# !pip install --trusted-host pypi.org ipython-sql

# %%
# !pip install ipython-sql
# !pip install sqlalchemy

# %%
import pandas as pd
import psycopg2
import sqlalchemy
import matplotlib as plt

# %matplotlib inline

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
from sqlalchemy import create_engine

# %%
# Example format
# %sql postgresql://postgres:1234@localhost/postgres
# Out:
# 'Connected: postgres@postgres'

# %%
# Example format
engine = create_engine('postgresql://postgres:1234@localhost/postgres')

# %%
# %%sql
#
# SELECT data_relatorio, suspeitos, confirmados, nao_confirmados, aguarda_resultados, recuperados, obitos, em_vigilancia, importados, internados
# FROM situacao_epidemiologica
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 55 rows affected.
# [(datetime.date(2020, 3, 7), 224, 21, None, 47, None, 0, 412, 5, 21),
#  (datetime.date(2020, 3, 8), 281, 30, None, 56, None, 0, 447, 6, 30),
#  (datetime.date(2020, 3, 10), 375, 41, None, 83, None, 0, 667, 8, 40),
#  (datetime.date(2020, 3, 13), 1308, 112, None, 172, None, 0, 5674, 33, 107),
#  (datetime.date(2020, 3, 14), 1704, 169, None, 126, 1, 0, 5011, 39, 114),
#  (datetime.date(2020, 3, 16), 2908, 331, 2203, 374, 3, 0, 4592, 47, 139),
#  (datetime.date(2020, 3, 18), 5067, 642, 4074, 351, 3, 0, 6656, 62, 89),
#  (datetime.date(2020, 3, 20), 7732, 1020, 5862, 850, 5, 0, 9008, 95, 126),
#  (datetime.date(2020, 3, 21), 9854, 1280, 7515, 1059, 5, 0, 13155, 104, 156),
#  (datetime.date(2020, 3, 31), 52086, 7443, 40033, 4610, 43, 160, 19260, None, 627),
#  (datetime.date(2020, 3, 3), 101, 4, None, None, None, 0, None, 2, None),
# ...

# %%
dados = pd.read_sql('SELECT data_relatorio, suspeitos, confirmados, nao_confirmados, aguarda_resultados, recuperados, obitos, em_vigilancia, importados, internados FROM situacao_epidemiologica', engine)

dados
# Out:
#    data_relatorio  suspeitos  confirmados  nao_confirmados  \
# 0      2020-03-07        224           21              NaN
# 1      2020-03-08        281           30              NaN
# 2      2020-03-10        375           41              NaN
# 3      2020-03-13       1308          112              NaN
# 4      2020-03-14       1704          169              NaN
# 5      2020-03-16       2908          331           2203.0
# 6      2020-03-18       5067          642           4074.0
# 7      2020-03-20       7732         1020           5862.0
# 8      2020-03-21       9854         1280           7515.0
# 9      2020-03-31      52086         7443          40033.0
# 10     2020-03-03        101            4              NaN
# 11     2020-04-26     236410        23864         207873.0
# 12     2020-04-22     210302        21982         185101.0
# 13     2020-04-25     231737        23392         203562.0
# 14     2020-03-09        339           39              NaN
# ...
